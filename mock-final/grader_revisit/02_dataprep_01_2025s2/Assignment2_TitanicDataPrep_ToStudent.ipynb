# %% [markdown]
# # Assignment: Preparing Data for Analysis (Modified Titanic)

# %% [markdown]
# ![](https://github.com/kaopanboonyuen/2110446_DataScience_2021s2/raw/main/%20files/hw.png)

# %% [markdown]
# # 1) Load data & review the data
#
# How many rows are there in the "titanic_to_student.csv"?

# %%
#Import the libraries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('titanic_to_student.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            2       1.0     1.0
# 1           1            4       1.0     1.0
# 2           2            6       0.0     3.0
# 3           3            8       0.0     3.0
# 4           4           10       1.0     2.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 2                                   Moran, Mr. James    male   NaN    0.0
# 3                     Palsson, Master. Gosta Leonard    male   2.0    3.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
#
#      Ticket     Fare Embarked
# 0  PC 17599  71.2833        C
# 1    113803  53.1000        S
# 2    330877   8.4583        Q
# 3    349909  21.0750        S
# 4    237736  30.0708        C

# %%
df = df.set_index('PassengerId')

# %%
df.shape[0]
# Out:
# 445

# %% [markdown]
# # 2) Drop unqualified variables
# 2.1 Drop variables with missing > 50%
#
# 2.2 Check all columns except 'Age' and 'Fare' for flat values, drop the columns where flat value > 70%
# From 2.1 and 2.2, how many columns do we have left?
#
# Note:
#
#     -Ensure missing values are considered in your calculation. If you use normalize in .value_counts(), please include dropna=False.

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            2       1.0     1.0
# 1           1            4       1.0     1.0
# 2           2            6       0.0     3.0
# 3           3            8       0.0     3.0
# 4           4           10       1.0     2.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 2                                   Moran, Mr. James    male   NaN    0.0
# 3                     Palsson, Master. Gosta Leonard    male   2.0    3.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 1      0    113803  53.1000  C123        S
# 2      0    330877   8.4583   NaN        Q
# 3      1    349909  21.0750   NaN        S
# 4      0    237736  30.0708   NaN        C

# %% [markdown]
# ## 2.1

# %%
df.isna().sum(axis=0)/df.shape[0] > 0.5
# Out:
# Unnamed: 0    False
# Survived      False
# Pclass        False
# Name          False
# Sex           False
# Age           False
# SibSp         False
# Parch         False
# Ticket        False
# Fare          False
# Cabin          True
# Embarked      False
# dtype: bool

# %%
df = df.drop(axis=1, labels=['Cabin'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 2.2

# %%
(df['Ticket'].value_counts(dropna=False) / df.shape[0]).max()
# Out:
# np.float64(0.04269662921348315)

# %%
flagged = []
for feat in df.columns:
    max_unique = (df[feat].value_counts(dropna=False) / df.shape[0]).max()
    if max_unique > 0.7:
        flagged.append(feat)

# %%
flagged
# Out:
# ['Parch']

# %%
df = df.drop(labels=flagged, axis=1)

# %%
print('Left with',df.shape[1],'cols')
# Out:
# Left with 10 cols

# %% [markdown]
# # 3) Remove all rows with missing target (the variable "Survived")
#
# Remove all rows with missing targets (the variable "Survived")
#
# How many rows do we have left?

# %%
df = df[~df['Survived'].isna()]

# %%
df.shape[0]
# Out:
# 432

# %% [markdown]
# # 4) Handle outliers
# Handle outliers
#
# For the variable “Fare”, replace outlier values with the boundary values
#
# If value < (Q1 - 1.5IQR), replace with (Q1 - 1.5IQR)
#
# If value > (Q3 + 1.5IQR), replace with (Q3 + 1.5IQR)
#
# What is the average (mean) of “Fare” after replacing the outliers (round 2 decimal points)?
#
# Hint: Use function round(_, 2)

# %%
quartiles = df['Fare'].quantile([0.25,0.5,0.75])
quartiles
# Out:
# 0.25     7.91770
# 0.50    15.24580
# 0.75    34.10935
# Name: Fare, dtype: float64

# %%
iqr = quartiles[0.75] - quartiles[0.25]

# %%
lower = quartiles[0.25] - 1.5*iqr
upper = quartiles[0.75] + 1.5*iqr

# %%
df['Fare'] = df['Fare'].clip(lower=lower, upper=upper)

# %%
round(df['Fare'].mean(),2)
# Out:
# np.float64(26.23)

# %% [markdown]
# # 5) Impute missing value
#
# Impute missing value
#
# For number type column, impute missing values with mean
#
# What is the average (mean) of “Age” after imputing the missing values (round 2 decimal points)?
#
# Hint: Use function round(_, 2)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#              Unnamed: 0  Survived  Pclass  \
# PassengerId
# 2                     0       1.0     1.0
# 4                     1       1.0     1.0
# 6                     2       0.0     3.0
# 8                     3       0.0     3.0
# 10                    4       1.0     2.0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6                                             Moran, Mr. James    male   NaN
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp    Ticket     Fare Embarked
# PassengerId
# 2              1.0  PC 17599  71.2833        C
# 4              1.0    113803  53.1000        S
# 6              0.0    330877   8.4583        Q
# 8              3.0    349909  21.0750        S
# 10             1.0    237736  30.0708        C

# %%
number_cols = ['Age','Fare', 'SibSp']

# %%
for col in number_cols:
    df.loc[df[col].isna(), col] = df[col].mean()

# %%
df['Age'].mean()
# Out:
# np.float64(29.332636103151863)

# %% [markdown]
# # 6) Convert categorical to numeric values
#
# Convert categorical to numeric values
#
# For the variable “Embarked”, perform the dummy coding.
#
# What is the average (mean) of “Embarked_Q” after performing dummy coding (round 2 decimal points)?
#
# Hint: Use function round(_, 2)

# %%
df.head()
# Out:
#              Unnamed: 0  Survived  Pclass  \
# PassengerId
# 2                     0       1.0     1.0
# 4                     1       1.0     1.0
# 6                     2       0.0     3.0
# 8                     3       0.0     3.0
# 10                    4       1.0     2.0
#
#                                                           Name     Sex  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 6                                             Moran, Mr. James    male
# 8                               Palsson, Master. Gosta Leonard    male
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female
#
#                    Age  SibSp    Ticket     Fare Embarked
# PassengerId
# 2            38.000000    1.0  PC 17599  71.2833        C
# 4            35.000000    1.0    113803  53.1000        S
# 6            29.332636    0.0    330877   8.4583        Q
# 8             2.000000    3.0    349909  21.0750        S
# 10           14.000000    1.0    237736  30.0708        C

# %%
cat_col = ['Sex', 'Embarked']
for col in cat_col:
    if col == 'Sex':
        df[col] = df[col].astype('category').cat.codes
    else:
        df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)

# %%
df['Embarked_Q'].mean().round(2)
# Out:
# np.float64(0.06)

# %% [markdown]
# # 7) Partition data
# Split train/test split with stratification using 70%:30% and random seed with 123
#
# Show a proportion between survived (1) and died (0) in all data sets (total data, train, test)
#
# What is the proportion of survivors (survived = 1) in the training data (round 2 decimal points)?
#
# Hint: Use function round(_, 2), and train_test_split() from sklearn.model_selection

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Ticket', 'Fare', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
X = df[['Unnamed: 0', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Ticket', 'Fare', 'Embarked_Q', 'Embarked_S']]
y = df['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=123, stratify=df['Survived'])

# %%
print(
    ((df["Survived"] == 1).sum() / df.shape[0]).round(2),
    ((y_train == 1).sum() / y_train.shape[0]).round(2),
    ((y_test == 1).sum() / y_test.shape[0]).round(2),
)
# Out:
# 0.42 0.42 0.42
